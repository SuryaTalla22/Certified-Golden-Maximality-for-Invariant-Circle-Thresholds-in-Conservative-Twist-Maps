# %% [markdown]
# # Environment and Smoke Checks
#
# Bootstrap the package and run the smallest end-to-end checks.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = None
for cand in [Path.cwd(), Path.cwd().parent, *Path.cwd().parents]:
    if (cand / "kam_theorem_suite").exists():
        PROJECT_ROOT = cand
        break
if PROJECT_ROOT is None:
    raise RuntimeError("Could not locate project root containing kam_theorem_suite")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("PROJECT_ROOT =", PROJECT_ROOT)
# Out:
# PROJECT_ROOT = /mnt/data/work_stage/project

# %%
import kam_theorem_suite as kts
from kam_theorem_suite.proof_driver import build_periodic_class_report

rep = build_periodic_class_report((1,))
rep.to_dict()
# Out:
# {'label': '[(1)]',
#  'rho': 1.618033988749895,
#  'eta_approx': 0.4472135954999579,
#  'eta_cycle': {'period': (1,),
#   'rho': 1.618033988749895,
#   'eta_lo': 0.4471840315680842,
#   'eta_hi': 0.44729099487844454,
#   'eta_center': 0.4472272991360122,
#   'phase_stats': [{'phase': 0,
#     'eta_lo': 0.4471840315680842,
#     'eta_hi': 0.44729099487844454,
#     'eta_center': 0.4472092821804276,
#     'samples': 4}],
#   'burn_in_cycles': 8,
#   'dps': 120}}

# %%
from kam_theorem_suite.proof_driver import build_branch_report

branch = build_branch_report(3, 5, 0.9708, 0.9710)
{
    "max_endpoint_radius": branch["max_endpoint_radius"],
    "tube_sup_width": branch["tube_sup_width"],
    "message": branch["message"],
}
# Out:
# {'max_endpoint_radius': 7.716884829811477e-06,
#  'tube_sup_width': 1.5433769659622953e-05,
#  'message': 'built from midpoint solve + endpoint continuation; interval tangent inclusion succeeded'}
