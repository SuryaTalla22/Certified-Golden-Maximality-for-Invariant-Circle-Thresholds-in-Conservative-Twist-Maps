# %% [markdown]
# # Adaptive Class Campaigns
#
# Compare the older fixed-window campaign layer against the new adaptive policy.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = None
for cand in [Path.cwd(), Path.cwd().parent, *Path.cwd().parents]:
    if (cand / "kam_theorem_suite").exists():
        PROJECT_ROOT = cand
        break
if PROJECT_ROOT is None:
    raise RuntimeError("Could not locate project root containing kam_theorem_suite")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print({"project_root": str(PROJECT_ROOT)})
# Out:
# {'project_root': '/mnt/data/work_stage/project'}

# %%
from kam_theorem_suite import ArithmeticClassSpec
from kam_theorem_suite.proof_driver import build_class_atlas_campaign_report, build_adaptive_class_campaign_report

silver = ArithmeticClassSpec(preperiod=(), period=(2,), label="silver")
fixed = build_class_atlas_campaign_report(
    silver,
    reference_lower_bound=0.97122,
    reference_crossing_center=0.97130,
    max_q=20,
    keep_last=2,
    q_min=2,
    auto_localize_crossing=True,
    min_width=1e-3,
)
adaptive = build_adaptive_class_campaign_report(
    silver,
    reference_lower_bound=0.97122,
    reference_crossing_center=0.97130,
    max_q=20,
    keep_last=2,
    q_min=2,
    auto_localize_crossing=True,
    min_width=1e-3,
    max_attempts_per_approximant=2,
)
{
    "fixed_status": fixed["atlas"]["atlas_status"],
    "adaptive_status": adaptive["status"],
    "adaptive_crossings": adaptive["certified_crossing_count"],
    "adaptive_failures": adaptive["failed_entry_count"],
}
# Out:
# {'fixed_status': 'exploratory-atlas',
#  'adaptive_status': 'partially-adaptive-certified-campaign',
#  'adaptive_crossings': 1,
#  'adaptive_failures': 1}

# %%
adaptive["entries"][0]["attempts"][0]
# Out:
# {'p': 12,
#  'q': 5,
#  'label': '12/5',
#  'attempt_index': 0,
#  'predictor_method': 'reference-center',
#  'predicted_center': 0.9713,
#  'crossing_half_width': 0.0025,
#  'crossing_window_lo': 0.9688000000000001,
#  'crossing_window_hi': 0.9738,
#  'reference_center': 0.9713,
#  'bridge_status': 'hyperbolic-band-only',
#  'crossing_certification_tier': 'incomplete',
#  'crossing_root_window_lo': None,
#  'crossing_root_window_hi': None,
#  'crossing_root_center': None,
#  'first_supercritical_gap': None,
#  'used_reference_blend': False,
#  'report': {'p': 12,
#   'q': 5,
#   'crossing_window_input_lo': 0.9688000000000001,
#   'crossing_window_input_hi': 0.9738,
#   'band_search_lo': 0.9748,
#   'band_search_hi': 0.9893000000000001,
#   'target_residue': 0.25,
#   'crossing_certificate': {'p': 12,
#    'q': 5,
#    'K_lo': 0.9737583333333333,
#    'K_hi': 0.9738,
#    'target_residue': 0.25,
#    'localization_scan_used': True,
#    'endpoint_left': {'p': 12,
#     'q': 5,
# ...

# %%
adaptive["pruning_against_reference"]
# Out:
# {'golden_lower_bound': 0.97122,
#  'records': [{'label': '29/12',
#    'preperiod': (),
#    'period': (2,),
#    'rho': 2.414213562373095,
#    'eta_lo': 0.3535533905865015,
#    'eta_hi': 0.3535533906327456,
#    'eta_center': 0.3535533906016893,
#    'arithmetic_method': 'periodic-cycle',
#    'threshold_lower_bound': None,
#    'threshold_upper_bound': None,
#    'status': 'arithmetic-weaker-only',
#    'reason': 'eta interval lies strictly below the golden eta but no threshold upper bound is available'},
#   {'label': '12/5',
#    'preperiod': (),
#    'period': (2,),
#    'rho': 2.414213562373095,
#    'eta_lo': 0.3535533905865015,
#    'eta_hi': 0.3535533906327456,
#    'eta_center': 0.3535533906016893,
#    'arithmetic_method': 'periodic-cycle',
#    'threshold_lower_bound': 0.9738789226171458,
#    'threshold_upper_bound': 0.9738789749354367,
#    'status': 'overlapping',
#    'reason': 'threshold upper bound still overlaps the trusted golden lower bound'}],
# ...
