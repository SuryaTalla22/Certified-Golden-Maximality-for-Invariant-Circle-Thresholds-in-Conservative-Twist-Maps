# %% [markdown]
# # Golden supercritical localization
#
# This notebook exercises the adaptive localization layer for the golden upper-side continuation bridge.

# %%
from pathlib import Path
import sys, json

ROOT = Path.cwd()
for candidate in [ROOT, ROOT.parent]:
    if (candidate / 'kam_theorem_suite').exists():
        ROOT = candidate
        break
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
print(ROOT)
# Out:
# /mnt/data/work_next/stage

# %%
from kam_theorem_suite import (
    build_golden_supercritical_localization_report,
    build_golden_two_sided_localization_bridge_report,
)

localization = build_golden_supercritical_localization_report(
    n_terms=5,
    keep_last=2,
    min_q=5,
    crossing_center_offsets=(-4.0e-4, 0.0, 4.0e-4),
    initial_subdivisions=1,
    max_depth=0,
    refine_upper_ladder=False,
    max_rounds=2,
)
print(json.dumps({
    'status': localization['theorem_status'],
    'rounds': localization['total_round_count'],
    'best_round_status': localization['best_round_status'],
    'localized_upper_lo': localization['localized_upper_lo'],
    'localized_upper_hi': localization['localized_upper_hi'],
}, indent=2))
# Out:
# {
#   "status": "golden-supercritical-localization-failed",
#   "rounds": 1,
#   "best_round_status": "golden-supercritical-continuation-failed",
#   "localized_upper_lo": null,
#   "localized_upper_hi": null
# }

# %%
bridge = build_golden_two_sided_localization_bridge_report(
    K_values=[0.3],
    N_values=(24,),
    use_multiresolution=False,
    n_terms=5,
    keep_last=2,
    min_q=5,
    crossing_center_offsets=(-4.0e-4, 0.0, 4.0e-4),
    initial_subdivisions=1,
    max_depth=0,
    refine_upper_ladder=False,
    max_rounds=2,
)
print(json.dumps({
    'status': bridge['theorem_status'],
    'relation': bridge['relation'],
}, indent=2))
# Out:
# {
#   "status": "golden-two-sided-localization-incomplete",
#   "relation": {
#     "lower_bound_K": null,
#     "upper_object_source": "no-stable-upper-object",
#     "upper_crossing_lo": null,
#     "upper_crossing_hi": null,
#     "upper_crossing_width": null,
#     "gap_to_upper_crossing": null,
#     "gap_to_localized_hyperbolic_band": null,
#     "lower_success_prefix_len": 0,
#     "upper_support_size": 0,
#     "upper_round_count": 1,
#     "status": "golden-two-sided-localization-incomplete"
#   }
# }
