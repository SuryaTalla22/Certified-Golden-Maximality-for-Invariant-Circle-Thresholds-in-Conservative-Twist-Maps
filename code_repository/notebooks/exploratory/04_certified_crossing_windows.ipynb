# %% [markdown]
# # Certified Crossing Windows
#
# Build a local unique crossing certificate and inspect the refined root window.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = None
for cand in [Path.cwd(), Path.cwd().parent, *Path.cwd().parents]:
    if (cand / "kam_theorem_suite").exists():
        PROJECT_ROOT = cand
        break
if PROJECT_ROOT is None:
    raise RuntimeError("Could not locate project root containing kam_theorem_suite")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("PROJECT_ROOT =", PROJECT_ROOT)
# Out:
# PROJECT_ROOT = /mnt/data/work_stage/project

# %%
from kam_theorem_suite.proof_driver import build_unique_crossing_certificate_report

rep = build_unique_crossing_certificate_report(3, 5, 0.9708, 0.9710, auto_localize=True)
{
    "status": rep["status"],
    "root_window": [rep["root_window_lo"], rep["root_window_hi"]],
    "derivative_sign": rep["derivative_sign"],
}
# Out:
# {'status': 'incomplete',
#  'root_window': [None, None],
#  'derivative_sign': 'positive'}
