# %% [markdown]
# # Irrational Torus Validation
#
# Run the finite-dimensional irrational-circle validator and inspect bridge-quality diagnostics.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = None
for cand in [Path.cwd(), Path.cwd().parent, *Path.cwd().parents]:
    if (cand / "kam_theorem_suite").exists():
        PROJECT_ROOT = cand
        break
if PROJECT_ROOT is None:
    raise RuntimeError("Could not locate project root containing kam_theorem_suite")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("PROJECT_ROOT =", PROJECT_ROOT)
# Out:
# PROJECT_ROOT = /mnt/data/work_stage/project

# %%
from kam_theorem_suite.proof_driver import build_torus_validation_report

golden = (5 ** 0.5 - 1.0) / 2.0
rep = build_torus_validation_report(golden, 0.90, N=64)
{
    "success": rep["success"],
    "radius": rep["radius"],
    "bridge_quality": rep["bridge_quality"],
    "oversampled_residual_inf": rep["oversampled_residual_inf"],
}
# Out:
# {'success': True,
#  'radius': 5.249168396523993e-16,
#  'bridge_quality': 'moderate',
#  'oversampled_residual_inf': 2.6978319031841484e-06}
