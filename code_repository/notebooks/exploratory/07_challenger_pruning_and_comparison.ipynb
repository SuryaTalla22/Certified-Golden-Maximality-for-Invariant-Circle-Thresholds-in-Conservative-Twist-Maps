# %% [markdown]
# # Challenger Pruning and Comparison
#
# Turn atlas outputs into a challenger-pruning table.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = None
for cand in [Path.cwd(), Path.cwd().parent, *Path.cwd().parents]:
    if (cand / "kam_theorem_suite").exists():
        PROJECT_ROOT = cand
        break
if PROJECT_ROOT is None:
    raise RuntimeError("Could not locate project root containing kam_theorem_suite")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print("PROJECT_ROOT =", PROJECT_ROOT)
# Out:
# PROJECT_ROOT = /mnt/data/work_stage/project

# %%
from kam_theorem_suite import ChallengerSpec
from kam_theorem_suite.proof_driver import build_challenger_pruning_report_driver

challengers = [
    ChallengerSpec(preperiod=(), period=(2,), threshold_upper_bound=0.9600, label="silver sample"),
    ChallengerSpec(preperiod=(), period=(3,), threshold_upper_bound=0.9720, label="bronze-ish sample"),
]
rep = build_challenger_pruning_report_driver(challengers, golden_lower_bound=0.97122)
{
    "status": rep["status"],
    "dominated_count": rep["dominated_count"],
    "overlapping_count": rep["overlapping_count"],
}
# Out:
# {'status': 'partially-pruned', 'dominated_count': 1, 'overlapping_count': 1}
