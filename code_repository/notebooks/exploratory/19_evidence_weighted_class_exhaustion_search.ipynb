# %% [markdown]
# # Evidence-Weighted Class Exhaustion Search
#
# This notebook exercises the new round-history-aware challenger search loop. It reuses the same class-level exhaustion infrastructure as the earlier adaptive search, but it now learns from persistence, productivity, and wasted budget across rounds.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print(ROOT)

# %%
from kam_theorem_suite import ArithmeticClassSpec, build_evidence_weighted_class_exhaustion_search_report

# %%
specs = [
    ArithmeticClassSpec(preperiod=(), period=(2,), label='silver'),
    ArithmeticClassSpec(preperiod=(), period=(3,), label='bronze'),
    ArithmeticClassSpec(preperiod=(), period=(1, 2), label='mixed'),
]
report = build_evidence_weighted_class_exhaustion_search_report(
    specs,
    reference_crossing_center=0.97135,
    reference_lower_bound=0.9711,
    rounds=3,
    per_round_budget=2,
    initial_max_q=21,
    max_q_step=8,
    initial_keep_last=2,
    q_min=2,
    initial_subdivisions=2,
    max_depth=2,
    min_width=1e-3,
)
report['status']

# %%
[(r['round_index'], r['top_priority_classes'], r['escalated_classes']) for r in report['rounds']]

# %%
[(r['class_label'], r['pruning_status'], round(float(r['priority_score']), 3), r['priority_reason']) for r in report['final_records']]
