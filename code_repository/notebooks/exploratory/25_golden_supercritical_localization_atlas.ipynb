# %% [markdown]
# # Golden supercritical localization atlas
#
# This notebook exercises the new evidence-accumulating golden upper-side atlas.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from kam_theorem_suite.proof_driver import build_golden_supercritical_localization_atlas_report

# %%
atlas = build_golden_supercritical_localization_atlas_report(
    n_terms=3,
    keep_last=1,
    min_q=5,
    crossing_center_offsets=(0.0,),
    atlas_center_offsets=(-6.0e-4, 0.0, 6.0e-4),
    initial_subdivisions=1,
    max_depth=0,
    refine_upper_ladder=False,
    max_rounds=1,
)
{
    'status': atlas['theorem_status'],
    'successful_entry_count': atlas['successful_entry_count'],
    'clustered_entry_count': atlas['clustered_entry_count'],
    'atlas_upper_source': atlas['atlas_upper_source'],
}
# Out:
# {'status': 'golden-supercritical-localization-atlas-weak',
#  'successful_entry_count': 1,
#  'clustered_entry_count': 1,
#  'atlas_upper_source': 'raw-upper-ladder'}
