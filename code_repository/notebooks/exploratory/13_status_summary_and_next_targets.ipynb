# %% [markdown]
# # Status Summary and Next Targets
#
# Updated after the multi-source seed atlas stage.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = None
for cand in [Path.cwd(), Path.cwd().parent, *Path.cwd().parents]:
    if (cand / 'kam_theorem_suite').exists():
        PROJECT_ROOT = cand
        break
if PROJECT_ROOT is None:
    raise RuntimeError('Could not locate project root')
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print('PROJECT_ROOT =', PROJECT_ROOT)
# Out:
# PROJECT_ROOT = /mnt/data/rebuild2/stage

# %%
from kam_theorem_suite import ArithmeticClassSpec
from kam_theorem_suite.proof_driver import build_seeded_multi_class_campaign_report
classes = [
    ArithmeticClassSpec(preperiod=(), period=(2,), label='silver'),
    ArithmeticClassSpec(preperiod=(), period=(3,), label='bronze'),
]
summary = build_seeded_multi_class_campaign_report(
    classes,
    reference_lower_bound=0.97122,
    reference_crossing_center=0.97130,
    max_q=12,
    keep_last=1,
    q_min=2,
    auto_localize_crossing=True,
    min_width=1e-3,
    max_attempts_per_approximant=2,
)
{
    'class_count': len(summary['class_campaigns']),
    'total_seed_reuse_count': summary['total_seed_reuse_count'],
    'dominated_classes': summary['dominated_classes'],
    'overlapping_classes': summary['overlapping_classes'],
    'undecided_classes': summary['undecided_classes'],
}
# Out:
# {'class_count': 2,
#  'total_seed_reuse_count': 0,
#  'dominated_classes': [],
#  'overlapping_classes': [],
#  'undecided_classes': ['silver', 'bronze']}

# %%
summary['class_campaigns'][0]['entries'][:1]
# Out:
# [{'p': 29,
#   'q': 12,
#   'label': '29/12',
#   'order_index': 0,
#   'rho_error': 0.002453104293571595,
#   'final_status': 'failed',
#   'attempts': [{'p': 29,
#     'q': 12,
#     'label': '29/12',
#     'attempt_index': 0,
#     'predicted_center': 0.9713,
#     'crossing_half_width': 0.0025,
#     'crossing_window_lo': 0.9688000000000001,
#     'crossing_window_hi': 0.9738,
#     'predictor_method': 'reference-center',
#     'seed_source_label': None,
#     'seed_transfer': None,
#     'seed_selected_method': None,
#     'seed_selected_residual_inf': None,
#     'bridge_status': 'incomplete',
#     'crossing_certification_tier': 'incomplete',
#     'crossing_root_window_lo': None,
#     'crossing_root_window_hi': None,
#     'crossing_root_center': None,
#     'first_supercritical_gap': None,
#     'report': {'p': 29,
#      'q': 12,
#      'crossing_window_input_lo': 0.9688000000000001,
#      'crossing_window_input_hi': 0.9738,
#      'band_search_lo': 0.9748,
# ...
