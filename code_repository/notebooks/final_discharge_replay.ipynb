# %% [markdown]
# # Stage 108 final discharge replay
#
# Load regenerated upstream shells from your staged cache, build the Stage-108 final replay report, and save compact ledgers locally.

# %%
from pathlib import Path
from kam_theorem_suite.theorem_final_discharge_replay import (
    build_stage108_final_discharge_replay_report,
    save_stage108_final_discharge_artifacts,
    assert_stage108_final_discharge_verified,
)

# Replace these placeholders with loaded/regenerated theorem-facing shells.
# The Stage-108 test file contains a lightweight synthetic example.
stage_cache = Path('artifacts/final_discharge/stage_cache')
output_dir = stage_cache / 'stage108_replay'

# %% [markdown]
# The replay expects already-regenerated theorem-facing shell dictionaries for I--II, III, IV, compressed V, identification, VI, and VII.

# %%
# Example usage once shells are loaded:
# report = build_stage108_final_discharge_replay_report(
#     theorem_i_ii_workstream_certificate=theorem_i_ii,
#     theorem_iii_certificate=theorem_iii,
#     theorem_iv_certificate=theorem_iv,
#     theorem_v_certificate=theorem_v_compressed,
#     threshold_identification_certificate=threshold_identification,
#     theorem_vi_certificate=theorem_vi,
#     theorem_vii_certificate=theorem_vii_discharge,
# )
# assert_stage108_final_discharge_verified(report)
# save_stage108_final_discharge_artifacts(report, output_dir)
# report.to_dict()['theorem_viii_discharge_status']
